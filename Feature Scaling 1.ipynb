# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Feature Scaling --> It brings the data in one scale
# Standardization >> mu=0 and sigma=1
# Normalization >> (minmax scaling) >> data comes between 0 and 1
# Unit Vector

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Standardization through manually 
Mean=np.mean(df["total_bill"])
std=np.std(df["total_bill"])
std_data=[]
for i in list(df["total_bill"]):
    zscore=(i-Mean)/std
    std_data.append(zscore)
print(std_data)
# Out:
# [np.float64(-0.3147113050904943), np.float64(-1.0632353132988692), np.float64(0.13777989987156145), np.float64(0.43831510316725475), np.float64(0.540744704290506), np.float64(0.6195367051545455), np.float64(-1.2399545152367863), np.float64(0.7985071071171495), np.float64(-0.5342033074974614), np.float64(-0.5634689078183903), np.float64(-1.0711145133852733), np.float64(1.7417599174609364), np.float64(-0.49143050702841123), np.float64(-0.15262490331304146), np.float64(-0.557840907756673), np.float64(0.2019391005751361), np.float64(-1.0643609133112126), np.float64(-0.3935033059545337), np.float64(-0.31696250511518104), np.float64(0.09725829942719795), np.float64(-0.2100305039425557), np.float64(0.05673669898283484), np.float64(-0.45203450659639155), np.float64(2.2100095225958003), np.float64(0.003833498402694168), np.float64(-0.2224121040783337), np.float64(-0.7221785095588127), np.float64(-0.7987193103981653), np.float64(0.21544630072325727), np.float64(-0.015301701807144186), np.float
# ...

# %%
# Feature Scaling affects the distribution of data
# Out:
# [np.float64(-0.3147113050904943), np.float64(-1.0632353132988692), np.float64(0.13777989987156145), np.float64(0.43831510316725475), np.float64(0.540744704290506), np.float64(0.6195367051545455), np.float64(-1.2399545152367863), np.float64(0.7985071071171495), np.float64(-0.5342033074974614), np.float64(-0.5634689078183903), np.float64(-1.0711145133852733), np.float64(1.7417599174609364), np.float64(-0.49143050702841123), np.float64(-0.15262490331304146), np.float64(-0.557840907756673), np.float64(0.2019391005751361), np.float64(-1.0643609133112126), np.float64(-0.3935033059545337), np.float64(-0.31696250511518104), np.float64(0.09725829942719795), np.float64(-0.2100305039425557), np.float64(0.05673669898283484), np.float64(-0.45203450659639155), np.float64(2.2100095225958003), np.float64(0.003833498402694168), np.float64(-0.2224121040783337), np.float64(-0.7221785095588127), np.float64(-0.7987193103981653), np.float64(0.21544630072325727), np.float64(-0.015301701807144186), np.float
# ...

# %%
# sns.distplot(df["total_bill"])
sns.displot(df['total_bill'],kde=True)

# %%
sns.displot(std_data,kde=True)

# %%
# Standardization through Library
# mu,std --> .fit() and (i-mu)/std --> .transform()

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
scaler.fit(df[["total_bill"]]) # it will calculate mu and sigma
# Out:
# StandardScaler()

# %%
scaler.transform(df[["total_bill"]]) # It throws scaled Data
# Out:
# array([[-3.14711305e-01],
#        [-1.06323531e+00],
#        [ 1.37779900e-01],
#        [ 4.38315103e-01],
#        [ 5.40744704e-01],
#        [ 6.19536705e-01],
#        [-1.23995452e+00],
#        [ 7.98507107e-01],
#        [-5.34203307e-01],
#        [-5.63468908e-01],
#        [-1.07111451e+00],
#        [ 1.74175992e+00],
#        [-4.91430507e-01],
#        [-1.52624903e-01],
#        [-5.57840908e-01],
#        [ 2.01939101e-01],
#        [-1.06436091e+00],
#        [-3.93503306e-01],
#        [-3.16962505e-01],
#        [ 9.72582994e-02],
#        [-2.10030504e-01],
#        [ 5.67366990e-02],
#        [-4.52034507e-01],
#        [ 2.21000952e+00],
#        [ 3.83349840e-03],
#        [-2.22412104e-01],
#        [-7.22178510e-01],
#        [-7.98719310e-01],
#        [ 2.15446301e-01],
#        [-1.53017018e-02],
#        [-1.15215771e+00],
#        [-1.61629703e-01],
#        [-5.31952107e-01],
#        [ 1.01760699e-01],
#        [-2.25788904e-01],
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
scaler.fit_transform(df[["total_bill","tip"]])
# Out:
# array([[-3.14711305e-01, -1.43994695e+00],
#        [-1.06323531e+00, -9.69205340e-01],
#        [ 1.37779900e-01,  3.63355539e-01],
#        [ 4.38315103e-01,  2.25754144e-01],
#        [ 5.40744704e-01,  4.43019505e-01],
#        [ 6.19536705e-01,  1.23965916e+00],
#        [-1.23995452e+00, -7.22971264e-01],
#        [ 7.98507107e-01,  8.81527488e-02],
#        [-5.34203307e-01, -7.51939979e-01],
#        [-5.63468908e-01,  1.67816714e-01],
#        [-1.07111451e+00, -9.32994446e-01],
#        [ 1.74175992e+00,  1.44968234e+00],
#        [-4.91430507e-01, -1.03438495e+00],
#        [-1.52624903e-01,  1.24660453e-03],
#        [-5.57840908e-01,  1.57309619e-02],
#        [ 2.01939101e-01,  6.67527044e-01],
#        [-1.06436091e+00, -9.61963161e-01],
#        [-3.93503306e-01,  5.15441291e-01],
#        [-3.16962505e-01,  3.63355539e-01],
#        [ 9.72582994e-02,  2.54722859e-01],
#        [-2.10030504e-01,  7.83401903e-01],
#        [ 5.67366990e-02, -1.79807863e-01],
# ...

# %%
pd.DataFrame(scaler.fit_transform(df[["total_bill","tip"]]),columns=["Total_bill","Tip"])
# Out:
#      Total_bill       Tip
# 0     -0.314711 -1.439947
# 1     -1.063235 -0.969205
# 2      0.137780  0.363356
# 3      0.438315  0.225754
# 4      0.540745  0.443020
# ..          ...       ...
# 239    1.040511  2.115963
# 240    0.832275 -0.722971
# 241    0.324630 -0.722971
# 242   -0.221287 -0.904026
# 243   -0.113229  0.001247
#
# [244 rows x 2 columns]
